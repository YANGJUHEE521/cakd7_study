# %% [markdown]
# ### 네이버 검색 API 서비스
# - 참고) https://velog.io/@skarb4788/%EB%84%A4%EC%9D%B4%EB%B2%84-API-%EA%B2%80%EC%83%89

# %% [markdown]
# #### 블로그
# 네이버 개발자센터 > Documents > 서비스 API > 검색

# %% [markdown]
# ###### xml

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
#꼭 코드 그대로 쓰지않아도 됨 
import os
import sys
import urllib.request
client_id = "JiA0UcQbwk6j7_YjrUX9" #YOUR_CLIENT_ID
client_secret = "8C370YL7fQ"  #YOUR_CLIENT_SECRET


query = urllib.parse.quote(input("검색 질의"))  #검색할 단어 -> input 받기 
# url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의빅데이터
# ...

# %%
import warnings
warnings.filterwarnings('ignore')


#BeautifulSoup 이용해서 전처리 -> 텍스트만 뽑기

from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
bs = BeautifulSoup(xml, 'lxml')
bs.get_text()
# Out:
# "Naver Open API - blog ::'빅데이터'https://search.naver.comNaver Search ResultFri, 29 Jul 2022 02:52:55 +09001144020110<b>빅데이터</b>전문가 준비를 위한 체계적인 방법https://blog.naver.com/nam8853nam?Redirect=Log&logNo=222802704648그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터</b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... 율맘 스토리https://blog.naver.com/nam8853nam20220707<b>빅데이터</b>분석기사 실기 준비를 위한 학습루틴https://blog.naver.com/parkrapp?Redirect=Log&logNo=222753783578안녕하세요, 오늘은 제가 도전한 <b>빅데이터</b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터</b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... 황금빛 쭈롱월드https://blog.naver.com/parkrapp20220531<b>빅데이터</b>전문가 공부했던 과정https://blog.naver.com/kmin4015?Redirect=Log&logNo=222802560555<b>빅데이터</b>전문가 커리큘럼에서 다루고 있는 내용들은 1) 데이터 분석과 해석, 2) R 프로그램, 3) 요인 및 행렬, 4) 배열 및 리스트, 5) 패키지 등으로 구분해 볼 수 있는데요. 필요한 내용은 알차게 모두 구성되어 있는... 나날https://blog.naver.com/kmin401520220707<b>빅데이터</b>전문가 꼼꼼한 학습 노하우https://blog.naver.com/dbsrptkdgod?Redirect=Log&logNo=222
# ...

# %% [markdown]
# ###### json

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
#꼭 코드 그대로 쓰지않아도 됨 
import os
import sys
import urllib.request
client_id = "JiA0UcQbwk6j7_YjrUX9" #YOUR_CLIENT_ID
client_secret = "8C370YL7fQ"  #YOUR_CLIENT_SECRET


query = urllib.parse.quote(input("검색 질의"))  #검색할 단어 -> input 받기 
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의빅데이터
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 03:35:18 +0900",
# 	"total":1144129,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %% [markdown]
# #### Q. 네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.(api 가이드 참조 https://developers.naver.com/docs/serviceapi/search/web/web.md#%EC%9B%B9%EB%AC%B8%EC%84%9C)

# %%
import os
import sys
import urllib.request

client_id = "JiA0UcQbwk6j7_YjrUX9" #YOUR_CLIENT_ID
client_secret = "8C370YL7fQ"  #YOUR_CLIENT_SECRET


query = urllib.parse.quote(input("검색 질의"))  #검색할 단어 -> input 받기 
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
# 검색 질의빅데이터
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 03:35:21 +0900",
# 	"total":1144129,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %% [markdown]
# #### 과제 0728_1
# 웹문서에서 빅데이터에 대한 의미 있는 정보로 구성된 데이터 프레임을 출력하세요.

# %%
df
# Out:
#                      lastBuildDate    total  start  display  \
# 0  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 1  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 2  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 3  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 4  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 5  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 6  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 7  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 8  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
# 9  Fri, 29 Jul 2022 03:35:21 +0900  1144129      1       10
#
#                                                items
# 0  {'title': '<b>빅데이터</b>전문가 준비를 위한 체계적인 방법', 'li...
# 1  {'title': '<b>빅데이터</b>분석기사 실기 준비를 위한 학습루틴', 'l...
# 2  {'title': '<b>빅데이터</b>전문가 공부했던 과정', 'link': 'h...
# 3  {'title': '<b>빅데이터</b>전문가 꼼꼼한 학습 노하우', 'link':...
# ...

# %%
#칼럼 형성 
items_title = ["title", "link", "description", "bloggername", "bloggerlink", "postdate"]

#임의의 값으로 일단 채우기 
for it in items_title:
    df[it] = 1  

for i in range(len(df)):
    for it in items_title:
        df.loc[i, it] = df.loc[i, 'items'][it] 

# lastBuildDate - 검색 결과를 생성한 시간
# start- 검색 결과 문서 중, 문서의 시작점
# display -검색된 검색 결과의 개수
#items 
# 4개의 칼럼 삭제
df.drop(['lastBuildDate','items' , 'start', 'display'],axis = 1 , inplace = True)
df
# Out:
#      total                              title  \
# 0  1144129      <b>빅데이터</b>전문가 준비를 위한 체계적인 방법
# 1  1144129     <b>빅데이터</b>분석기사 실기 준비를 위한 학습루틴
# 2  1144129             <b>빅데이터</b>전문가 공부했던 과정
# 3  1144129          <b>빅데이터</b>전문가 꼼꼼한 학습 노하우
# 4  1144129         <b>빅데이터</b>전문가 대비하는 핵심 노하우
# 5  1144129  <b>빅데이터</b>학원 이젠 AWS클라우드까지 체계적으로!
# 6  1144129        국비지원 <b>빅데이터</b> 유형별 다양한 과정
# 7  1144129      <b>빅데이터</b> 자격증 준비 노하우와 활용 과정
# 8  1144129        <b>빅데이터</b>자격증 활용 방법 및 공부 팁
# 9  1144129        <b>빅데이터</b> 교육 단계별 맞춤형 학습과정
#
#                                                 link  \
# 0  https://blog.naver.com/nam8853nam?Redirect=Log...
# 1  https://blog.naver.com/parkrapp?Redirect=Log&l...
# 2  https://blog.naver.com/kmin4015?Redirect=Log&l...
# 3  https://blog.naver.com/dbsrptkdgod?Redirect=Lo...
# 4  https://blog.naver.com/zkfk1116?Redirect=Log&l...
# 5  https://blog.naver.com/jeongok8602?Redirect=Lo...
# 6  https://blog.naver.com/beany99?Redirect=Log&lo...
# ...

# %%
import re

mod = ['title', 'description']


for i in range(len(df)):
    for m in mod:
        df.loc[i, m] = re.sub('<.>|<..>', '', df.loc[i, m]) 
df
# Out:
#      total                       title  \
# 0  1144129      빅데이터전문가 준비를 위한 체계적인 방법
# 1  1144129     빅데이터분석기사 실기 준비를 위한 학습루틴
# 2  1144129             빅데이터전문가 공부했던 과정
# 3  1144129          빅데이터전문가 꼼꼼한 학습 노하우
# 4  1144129         빅데이터전문가 대비하는 핵심 노하우
# 5  1144129  빅데이터학원 이젠 AWS클라우드까지 체계적으로!
# 6  1144129        국비지원 빅데이터 유형별 다양한 과정
# 7  1144129      빅데이터 자격증 준비 노하우와 활용 과정
# 8  1144129        빅데이터자격증 활용 방법 및 공부 팁
# 9  1144129        빅데이터 교육 단계별 맞춤형 학습과정
#
#                                                 link  \
# 0  https://blog.naver.com/nam8853nam?Redirect=Log...
# 1  https://blog.naver.com/parkrapp?Redirect=Log&l...
# 2  https://blog.naver.com/kmin4015?Redirect=Log&l...
# 3  https://blog.naver.com/dbsrptkdgod?Redirect=Lo...
# 4  https://blog.naver.com/zkfk1116?Redirect=Log&l...
# 5  https://blog.naver.com/jeongok8602?Redirect=Lo...
# 6  https://blog.naver.com/beany99?Redirect=Log&lo...
# 7  https://blog.naver.com/sweety4338?Redirect=Log...
# ...

# %% [markdown]
# #### 과제 0728_2
# 뉴스, 영화, 쇼핑, 지식in, 카페글에서 적합한 주제에 대한 데이터를 가져와서
# 데이터 프레임으로 출력하세요.

# %%
#지식in

import os
import sys
import urllib.request

client_id = "JiA0UcQbwk6j7_YjrUX9" #YOUR_CLIENT_ID
client_secret = "8C370YL7fQ"  #YOUR_CLIENT_SECRET


query = urllib.parse.quote(input("궁금한 내용을 질문해주세요."))  #검색할 단어 -> input 받기 
url = 'https://openapi.naver.com/v1/search/kin.json' + query # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
# 궁금한 내용을 질문해주세요.고양이
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13856/1832508337.py in <module>
#      16 request.add_header("X-Naver-Client-Secret",client_secret)
#      17
# ---> 18 response = urllib.request.urlopen(request)
#      19 rescode = response.getcode()
#      20 if(rescode==200):
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# ...

# %% [markdown]
# #### 과제 0728_3
# #### 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)

# %%
#언어
# lang=kr
cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
skeys = '77825d684d216b56528b34b594de1d76'

url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={skeys}&lang=kr'

#  매개변수 형식을 사용하지 않는 경우 mode기본적으로 JSON
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13856/75714514.py in <module>
#      10 import urllib.request
#      11
# ---> 12 response = urllib.request.urlopen(url)
#      13 rescode = response.getcode()
#      14 if(rescode==200):
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     521         for processor in self.process_response.get(protocol, []):
#     522             meth = getattr(processor, meth_name)
# --> 523             response = meth(req, response)
#     524
# ...

# %%
def we_api(skey, city):
    
    url = 'https://api.openweathermap.org/data/2.5/weather'
    params = f'q={city}&appid={skeys}&lang=kr'
    query = url + params 
    
    request = Request(query)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
#     items = response_dict['body']['items']
    df = pd.DataFrame(response_dict)
    return df 
cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
skeys = '77825d684d216b56528b34b594de1d76'
city = cities[0]

we_api(skey, city)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13856/3166062839.py in <module>
#      17 city = cities[0]
#      18
# ---> 19 we_api(skey, city)
#
# ~\AppData\Local\Temp/ipykernel_13856/3166062839.py in we_api(skey, city)
#       7     request = Request(query)
#       8     request.get_method = lambda: 'GET'
# ----> 9     response_body = urlopen(request).read()
#      10
#      11     response_dict = json.loads(response_body.decode('utf-8'))
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py in open(self, fullurl, data, timeout)
# ...

# %% [markdown]
# #### 출력결과
# ```
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5
# ```

# %% [markdown]
# ## 공공데이터 api

# %% [markdown]
# #### 상가 업소정보

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json 


skey = 'Eeu%2BgWocavPoQbTCHqqMhBxWHE7i9DJ2iJ6jHTrSUjfLDEEYaOu0YAFQegLn8w8k9YPAP7cUV0%2FUc21r1VjuFw%3D%3D'
res_id = 'storezone'
stype = 'json'


#활용가이드 18p  #baroAPI 오퍼레이션 사용 -> 얘랑 위에 변수들로 밑에 코드 만든것 
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&key=9144&ServiceKey=서비스인증키

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
# urlencode({quote_plus('key'):'9174'} '9174'는 지금 문자잖아 얘만 변경되는 값이고, 
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + urlencode({quote_plus('key'):'9174'})
query = url + params 
print(query)

request = Request(query)
request.get_method = lambda: 'GET' # GET 방식 - 웹브라우저 주소창에 주소를 입력하고 웹사이트에 방문할 때 사용
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# df trarNo	상권번호
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=Eeu%2BgWocavPoQbTCHqqMhBxWHE7i9DJ2iJ6jHTrSUjfLDEEYaOu0YAFQegLn8w8k9YPAP7cUV0%2FUc21r1VjuFw%3D%3D&type=json&resId=storezone&key=9174
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = 'Eeu%2BgWocavPoQbTCHqqMhBxWHE7i9DJ2iJ6jHTrSUjfLDEEYaOu0YAFQegLn8w8k9YPAP7cUV0%2FUc21r1VjuFw%3D%3D'
res_id = 'storezone'
stype = 'json'

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+ urlencode({quote_plus('key'):'9174'})
query = url + params
print(query)

request = Request(query)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=Eeu%2BgWocavPoQbTCHqqMhBxWHE7i9DJ2iJ6jHTrSUjfLDEEYaOu0YAFQegLn8w8k9YPAP7cUV0%2FUc21r1VjuFw%3D%3D&type=json&resId=storezone&key=9174
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json 

def baro_api(skey, res_id, encode):
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + encode
    query = url + params 
    
    request = Request(query)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ### 상권조회

# %% [markdown]
# #### 지정 상권조회

# %%
skey = 'Eeu%2BgWocavPoQbTCHqqMhBxWHE7i9DJ2iJ6jHTrSUjfLDEEYaOu0YAFQegLn8w8k9YPAP7cUV0%2FUc21r1VjuFw%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey, res_id,encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# #### 반경내 상권조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=radius&radius=500&cx=127.004528&cy=37.567538&ServiceKey=서비스인증키

encode = urlencode({quote_plus('catId'):'radius', quote_plus('radius'):'500', quote_plus('cx'):'127.004528', quote_plus('cy'):'37.567538'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# #### 과제0728_4  사각형내 상권조회

# %%
#baroApi 오퍼레이션 
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=rectangle&minx=126.978020&miny=37.557825&maxx=126.987732&maxy=37.562022&ServiceKey=서비스인증키
encode = urlencode({quote_plus('catId'):'rectangle', quote_plus('minx'):'126.978020', quote_plus('miny'):'37.557825', quote_plus('maxx'):'126.987732', quote_plus('maxy'):'37.562022' })

baro_api(skey, res_id, encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9191      남대문시장       11    서울특별시    11140       중구    111020        27
# 1    9196        명동역       11    서울특별시    11140       중구     96649        28
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.976451547074 37.5576325944...  2021-06-30
# 1  MULTIPOLYGON (((126.983476244148 37.5605598377...  2021-06-30

# %% [markdown]
# #### 과제0728_5 행정단위 상권조회

# %%
# baroApi 오퍼레이션 
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=dong&divId=adongCd&key=1168069000&ServiceKey=서비스인증키

encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'adongCd', quote_plus('key'):'1168069000'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9324      포이사거리       11    서울특별시    11680      강남구     14033        33
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.044811833677 37.4781705036...  2021-06-30

# %% [markdown]
# ### 상가업소 조회

# %% [markdown]
# #### 행정동 단위 상가업소 조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=dong&divId=ctprvnCd&key=11&ServiceKey=서비스인증키

# resId 를 보면 store란 말이야 바뀌었으니까 다시 넣어줘야함
res_id = 'store'

    
encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'ctprvnCd', quote_plus('key'):'11'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
