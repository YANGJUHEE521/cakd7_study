# %%
|\_/|
|q p|   /}
( 0 )"""\
|"^"`    |
||_/=\\__|

# %%
print(r'|\_/|')
print('|q p|   /}')
print('( 0 )"""\\')
print('|"^"`    |')
print(r'||_/=\\__|')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
